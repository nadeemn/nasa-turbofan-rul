# %%
import os
import pandas as pd
import numpy as np
from kaggle_dataset import DatasetDownloader

column_names = ['unit_number', 'time', 'os_1', 'os_2', 'os_3']
sensor_measurements = [f'sm_{i}' for i in range(1, 22)]

column_names.extend(sensor_measurements)

downloader = DatasetDownloader("behrad3d/nasa-cmaps")
downloaded_path = downloader.download()

path = os.path.join(downloaded_path, 'CMaps', 'train_FD001.txt')
train_data = pd.read_csv(f'{path}', sep= ' ', header=None, names = column_names, index_col=False)
print(train_data)
# Out:
#        unit_number  time    os_1    os_2   os_3    sm_1    sm_2     sm_3  \
# 0                1     1 -0.0007 -0.0004  100.0  518.67  641.82  1589.70
# 1                1     2  0.0019 -0.0003  100.0  518.67  642.15  1591.82
# 2                1     3 -0.0043  0.0003  100.0  518.67  642.35  1587.99
# 3                1     4  0.0007  0.0000  100.0  518.67  642.35  1582.79
# 4                1     5 -0.0019 -0.0002  100.0  518.67  642.37  1582.85
# ...            ...   ...     ...     ...    ...     ...     ...      ...
# 20626          100   196 -0.0004 -0.0003  100.0  518.67  643.49  1597.98
# 20627          100   197 -0.0016 -0.0005  100.0  518.67  643.54  1604.50
# 20628          100   198  0.0004  0.0000  100.0  518.67  643.42  1602.46
# 20629          100   199 -0.0011  0.0003  100.0  518.67  643.23  1605.26
# 20630          100   200 -0.0032 -0.0005  100.0  518.67  643.85  1600.38
#
#           sm_4   sm_5  ...   sm_12    sm_13    sm_14   sm_15  sm_16  sm_17  \
# 0      1400.60  14.62  ...  521.66  2388.02  8138.62  8.4195   0.03    392
# 1      1403.14  14.62  ...  522.28  2388.07  8131.49  8.4318   0.03    392
# 2      1404.20  14.62  ...  522.42  2388.03  8133.23  8.4178   0.03    390
# 3      1401.87  14.62  ...  522.86  2388.08  8133.83  8.3682   0.03    392
# 4      1406.22  14.62  ...  522.19  2388.04  8133.80  8.4294   0.03    393
# ...        ...    ...  ...     ...      ...      ...     ...    ...    ...
# 20626  1428.63  14.62  ...  519.49  2388.26  8137.60  8.4956   0.03    397
# 20627  1433.58  14.62  ...  519.68  2388.22  8136.50  8.5139   0.03    395
# 20628  1428.18  14.62  ...  520.01  2388.24  8141.05  8.5646   0.03    398
# 20629  1426.53  14.62  ...  519.67  2388.23  8139.29  8.5389   0.03    395
# 20630  1432.14  14.62  ...  519.30  2388.26  8137.33  8.5036   0.03    396
#
#        sm_18  sm_19  sm_20    sm_21
# 0       2388  100.0  39.06  23.4190
# 1       2388  100.0  39.00  23.4236
# 2       2388  100.0  38.95  23.3442
# 3       2388  100.0  38.88  23.3739
# 4       2388  100.0  38.90  23.4044
# ...      ...    ...    ...      ...
# 20626   2388  100.0  38.49  22.9735
# 20627   2388  100.0  38.30  23.1594
# 20628   2388  100.0  38.44  22.9333
# 20629   2388  100.0  38.29  23.0640
# 20630   2388  100.0  38.37  23.0522
#
# [20631 rows x 26 columns]
# C:\Users\nadee\AppData\Local\Temp\ipykernel_28156\3062482007.py:15: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   train_data = pd.read_csv(f'{path}', sep= ' ', header=None, names = column_names, index_col=False)

# %%
df_info = pd.concat([train_data.isna().sum(), train_data.nunique(), train_data.dtypes], axis=1)

df_info.columns = ['missing value', 'number of unique value', 'data type']

df_info
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.
#              missing value  number of unique value data type
# unit_number              0                     100     int64
# time                     0                     362     int64
# os_1                     0                     158   float64
# os_2                     0                      13   float64
# os_3                     0                       1   float64
# sm_1                     0                       1   float64
# sm_2                     0                     310   float64
# sm_3                     0                    3012   float64
# sm_4                     0                    4051   float64
# sm_5                     0                       1   float64
# sm_6                     0                       2   float64
# sm_7                     0                     513   float64
# sm_8                     0                      53   float64
# sm_9                     0                    6403   float64
# sm_10                    0                       1   float64
# sm_11                    0                     159   float64
# sm_12                    0                     427   float64
# sm_13                    0                      56   float64
# sm_14                    0                    6078   float64
# sm_15                    0                    1918   float64
# sm_16                    0                       1   float64
# sm_17                    0                      13     int64
# sm_18                    0                       1     int64
# sm_19                    0                       1   float64
# sm_20                    0                     120   float64
# sm_21                    0                    4745   float64

# %%
df = train_data.copy()
print(df.shape)
# Out:
# (20631, 26)

# %%
def constant_features(df):
    constant_feature = []
    for col in df.columns:
        if abs(df[col].std() < 0.02):
            constant_feature.append(col)

    return constant_feature

# %%
print(constant_features(df=df))
# Out:
# ['os_1', 'os_2', 'os_3', 'sm_1', 'sm_5', 'sm_6', 'sm_10', 'sm_16', 'sm_18', 'sm_19']

# %%
df.drop(columns=constant_features(df), inplace=True)
df.columns
# Out:
# Index(['unit_number', 'time', 'sm_2', 'sm_3', 'sm_4', 'sm_7', 'sm_8', 'sm_9',
#        'sm_11', 'sm_12', 'sm_13', 'sm_14', 'sm_15', 'sm_17', 'sm_20', 'sm_21'],
#       dtype='object')

# %%
def rul(df):
    df['RUL'] = df.groupby('unit_number')['time'].transform('max') - df['time']

    return df

rul(df)
# Out:
#        unit_number  time    sm_2     sm_3     sm_4    sm_7     sm_8     sm_9  \
# 0                1     1  641.82  1589.70  1400.60  554.36  2388.06  9046.19
# 1                1     2  642.15  1591.82  1403.14  553.75  2388.04  9044.07
# 2                1     3  642.35  1587.99  1404.20  554.26  2388.08  9052.94
# 3                1     4  642.35  1582.79  1401.87  554.45  2388.11  9049.48
# 4                1     5  642.37  1582.85  1406.22  554.00  2388.06  9055.15
# ...            ...   ...     ...      ...      ...     ...      ...      ...
# 20626          100   196  643.49  1597.98  1428.63  551.43  2388.19  9065.52
# 20627          100   197  643.54  1604.50  1433.58  550.86  2388.23  9065.11
# 20628          100   198  643.42  1602.46  1428.18  550.94  2388.24  9065.90
# 20629          100   199  643.23  1605.26  1426.53  550.68  2388.25  9073.72
# 20630          100   200  643.85  1600.38  1432.14  550.79  2388.26  9061.48
#
#        sm_11   sm_12    sm_13    sm_14   sm_15  sm_17  sm_20    sm_21  RUL
# 0      47.47  521.66  2388.02  8138.62  8.4195    392  39.06  23.4190  191
# 1      47.49  522.28  2388.07  8131.49  8.4318    392  39.00  23.4236  190
# 2      47.27  522.42  2388.03  8133.23  8.4178    390  38.95  23.3442  189
# 3      47.13  522.86  2388.08  8133.83  8.3682    392  38.88  23.3739  188
# 4      47.28  522.19  2388.04  8133.80  8.4294    393  38.90  23.4044  187
# ...      ...     ...      ...      ...     ...    ...    ...      ...  ...
# 20626  48.07  519.49  2388.26  8137.60  8.4956    397  38.49  22.9735    4
# 20627  48.04  519.68  2388.22  8136.50  8.5139    395  38.30  23.1594    3
# 20628  48.09  520.01  2388.24  8141.05  8.5646    398  38.44  22.9333    2
# 20629  48.39  519.67  2388.23  8139.29  8.5389    395  38.29  23.0640    1
# 20630  48.20  519.30  2388.26  8137.33  8.5036    396  38.37  23.0522    0
#
# [20631 rows x 17 columns]

# %%
mask = np.triu(np.ones(df.shape).astype(bool))
mask
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [False,  True,  True, ...,  True,  True,  True],
#        [False, False,  True, ...,  True,  True,  True],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
df_corr = df.corr()
mask = np.tril(np.ones(df_corr.shape), k=-1).astype(bool)
df_corr = df_corr.where(mask)
df_corr
# Out:
#              unit_number      time      sm_2      sm_3      sm_4      sm_7  \
# unit_number          NaN       NaN       NaN       NaN       NaN       NaN
# time            0.078753       NaN       NaN       NaN       NaN       NaN
# sm_2            0.014133  0.549898       NaN       NaN       NaN       NaN
# sm_3            0.012621  0.543947  0.602610       NaN       NaN       NaN
# sm_4            0.026116  0.624577  0.714949  0.678413       NaN       NaN
# sm_7           -0.032073 -0.595914 -0.702136 -0.664595 -0.793130       NaN
# sm_8            0.039929  0.475977  0.662325  0.602481  0.746852 -0.767132
# sm_9           -0.052053  0.443999  0.273764  0.322964  0.297429 -0.217835
# sm_11           0.024707  0.634385  0.740020  0.695900  0.830136 -0.822805
# sm_12          -0.031882 -0.611354 -0.724578 -0.680307 -0.815591  0.812713
# sm_13           0.044230  0.477523  0.661792  0.600963  0.745158 -0.764611
# sm_14          -0.059473  0.370324  0.179752  0.237137  0.190748 -0.110053
# sm_15           0.022486  0.588676  0.675975  0.639921  0.758459 -0.747051
# sm_17           0.013513  0.566995  0.629886  0.600017  0.703499 -0.692893
# sm_20          -0.020589 -0.583597 -0.661841 -0.625941 -0.748067  0.736163
# sm_21          -0.016465 -0.585923 -0.668050 -0.633901 -0.745193  0.737447
# RUL             0.078753 -0.736241 -0.606484 -0.584520 -0.678948  0.657223
#
#                  sm_8      sm_9     sm_11     sm_12     sm_13     sm_14  \
# unit_number       NaN       NaN       NaN       NaN       NaN       NaN
# time              NaN       NaN       NaN       NaN       NaN       NaN
# sm_2              NaN       NaN       NaN       NaN       NaN       NaN
# sm_3              NaN       NaN       NaN       NaN       NaN       NaN
# sm_4              NaN       NaN       NaN       NaN       NaN       NaN
# sm_7              NaN       NaN       NaN       NaN       NaN       NaN
# sm_8              NaN       NaN       NaN       NaN       NaN       NaN
# sm_9        -0.032091       NaN       NaN       NaN       NaN       NaN
# sm_11        0.782213  0.274591       NaN       NaN       NaN       NaN
# sm_12       -0.786540 -0.210238 -0.846884       NaN       NaN       NaN
# sm_13        0.826084 -0.034763  0.780761 -0.788441       NaN       NaN
# sm_14       -0.144787  0.963157  0.163408 -0.098141 -0.147036       NaN
# sm_15        0.700949  0.293753  0.780913 -0.766052  0.697662  0.193761
# sm_17        0.627785  0.337110  0.722296 -0.703485  0.627410  0.246621
# sm_20       -0.687030 -0.285280 -0.771510  0.751943 -0.686172 -0.187364
# sm_21       -0.688840 -0.292795 -0.772554  0.756263 -0.688948 -0.192415
# RUL         -0.563968 -0.390102 -0.696228  0.671983 -0.562569 -0.306769
#
#                 sm_15     sm_17     sm_20     sm_21  RUL
# unit_number       NaN       NaN       NaN       NaN  NaN
# time              NaN       NaN       NaN       NaN  NaN
# sm_2              NaN       NaN       NaN       NaN  NaN
# sm_3              NaN       NaN       NaN       NaN  NaN
# sm_4              NaN       NaN       NaN       NaN  NaN
# sm_7              NaN       NaN       NaN       NaN  NaN
# sm_8              NaN       NaN       NaN       NaN  NaN
# sm_9              NaN       NaN       NaN       NaN  NaN
# sm_11             NaN       NaN       NaN       NaN  NaN
# sm_12             NaN       NaN       NaN       NaN  NaN
# sm_13             NaN       NaN       NaN       NaN  NaN
# sm_14             NaN       NaN       NaN       NaN  NaN
# sm_15             NaN       NaN       NaN       NaN  NaN
# sm_17        0.669205       NaN       NaN       NaN  NaN
# sm_20       -0.707671 -0.651021       NaN       NaN  NaN
# sm_21       -0.704043 -0.658710  0.693480       NaN  NaN
# RUL         -0.642667 -0.606154  0.629428  0.635662  NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

plt.figure(figsize=(12,5))
plt.grid(), plt.title('correlation')
sns.heatmap(df_corr, annot=True, fmt='0.2f', cmap='crest', linewidths=0.01)
# Out:
# <Axes: title={'center': 'correlation'}>

# %%
high_corr = []
for col in df_corr.columns:
    for row in df_corr.index:
        if abs(df_corr.loc[row, col]) > 0.95:
            high_corr.append((col,row))

high_corr
# Out:
# [('sm_9', 'sm_14')]

# %%
df.drop(columns=['sm_9'], inplace=True)

# %%
df
# Out:
#        unit_number  time    sm_2     sm_3     sm_4    sm_7     sm_8  sm_11  \
# 0                1     1  641.82  1589.70  1400.60  554.36  2388.06  47.47
# 1                1     2  642.15  1591.82  1403.14  553.75  2388.04  47.49
# 2                1     3  642.35  1587.99  1404.20  554.26  2388.08  47.27
# 3                1     4  642.35  1582.79  1401.87  554.45  2388.11  47.13
# 4                1     5  642.37  1582.85  1406.22  554.00  2388.06  47.28
# ...            ...   ...     ...      ...      ...     ...      ...    ...
# 20626          100   196  643.49  1597.98  1428.63  551.43  2388.19  48.07
# 20627          100   197  643.54  1604.50  1433.58  550.86  2388.23  48.04
# 20628          100   198  643.42  1602.46  1428.18  550.94  2388.24  48.09
# 20629          100   199  643.23  1605.26  1426.53  550.68  2388.25  48.39
# 20630          100   200  643.85  1600.38  1432.14  550.79  2388.26  48.20
#
#         sm_12    sm_13    sm_14   sm_15  sm_17  sm_20    sm_21  RUL
# 0      521.66  2388.02  8138.62  8.4195    392  39.06  23.4190  191
# 1      522.28  2388.07  8131.49  8.4318    392  39.00  23.4236  190
# 2      522.42  2388.03  8133.23  8.4178    390  38.95  23.3442  189
# 3      522.86  2388.08  8133.83  8.3682    392  38.88  23.3739  188
# 4      522.19  2388.04  8133.80  8.4294    393  38.90  23.4044  187
# ...       ...      ...      ...     ...    ...    ...      ...  ...
# 20626  519.49  2388.26  8137.60  8.4956    397  38.49  22.9735    4
# 20627  519.68  2388.22  8136.50  8.5139    395  38.30  23.1594    3
# 20628  520.01  2388.24  8141.05  8.5646    398  38.44  22.9333    2
# 20629  519.67  2388.23  8139.29  8.5389    395  38.29  23.0640    1
# 20630  519.30  2388.26  8137.33  8.5036    396  38.37  23.0522    0
#
# [20631 rows x 16 columns]

# %%
train_data['time'].describe()
# Out:
# count    20631.000000
# mean       108.807862
# std         68.880990
# min          1.000000
# 25%         52.000000
# 50%        104.000000
# 75%        156.000000
# max        362.000000
# Name: time, dtype: float64

# %%
failure_time = df.groupby('unit_number')['RUL'].max()
failure_time
# Out:
# unit_number
# 1      191
# 2      286
# 3      178
# 4      188
# 5      268
#       ...
# 96     335
# 97     201
# 98     155
# 99     184
# 100    199
# Name: RUL, Length: 100, dtype: int64

# %%
plt.figure(figsize=(6,14))
sns.barplot(y=failure_time.index, x=failure_time.values, orient='h')
plt.xlabel('Failure time')
plt.ylabel('Enginer number')
plt.title('Failure time for engine')
plt.tight_layout()
plt.show()

# %%
sns.histplot(failure_time, kde=True)
plt.title('failure time for enginer')
plt.tight_layout()

# %%
def plot_signal(df, signal_name):
    plt.figure(figsize=(10,4))

    for engine in df['unit_number'].unique():
        if engine%10 == 0:
            rolling_window = df[df['unit_number'] == engine].rolling(10).mean()
            sns.lineplot(data=rolling_window, x = 'rul', y=signal_name, label=engine)

    plt.tight_layout(), plt.xlim(250,0)
    plt.xlabel('RUL'), plt.ylabel(signal_name)
    plt.show()

# %%
for i in range(1,5):
    try:
        plot_signal(df, 'sm_'+str(i))

    except:
        pass
